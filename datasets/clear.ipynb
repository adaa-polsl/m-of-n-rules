# %%
from glob import glob
import shutil
import os

# %%
DATASETS = [
    'hayes-roth',
    'lymphography',
    'glass',
    'ecoli',
    'titanic',
    'anneal',
    'autos',
    'iris',
    'hepatitis',
    'heart-statlog',
    'cylinder-bands',
    'echocardiogram',
    'monk-2',
    'car',
    'nursery',
    'bupa-liver-disorders',
    'mushroom',
    'monk-1',
    'zoo',
    'auto-mpg',
    'monk-3',
    'balance-scale',
    'wine',
    'tic-tac-toe',
    'sonar',
    'flag',
    'cleveland',
    'heart-c',
    'vote',
    'soybean',
]

for path in glob('./classification/*'):
    if os.path.basename(path) not in DATASETS:
        shutil.rmtree(path)

# %%
DATASETS = [
    'diabetes',
    'gascons',
    'elusage',
    'mbagrade',
    'bolts',
    'kidney',
    'fruitfly',
    'cloud',
    'servo',
    'pollution',
    'concrete',
    'veteran',
    'fishcatch',
    'echomonths',
    'machine',
    'ele-1',
    'cpu',
    'lowbwt',
    'pyrim',
    'auto93',
    'pwlinear',
    'pharynx',
    'auto-price',
    'dee',
    'breasttumor',
    'ozone',
    'auto-mpg',
    'bodyfat',
    'cholesterol',
    'strike',
]


for path in glob('./regression/*'):
    if os.path.basename(path) not in DATASETS:
        shutil.rmtree(path)

# %%
DATASETS = [
    'Melanoma',
    'cancer',
    'mgus',
    'follic',
    'whas1',
    'GBSG2',
    'bmt-ch',
    'hd',
    'whas500',
    'pbc',
    'uis',
    'lung',
    'actg320',
    'std',
    'zinc',
    'wcgs',
]


for path in glob('./survival/*'):
    if os.path.basename(path) not in DATASETS:
        shutil.rmtree(path)
