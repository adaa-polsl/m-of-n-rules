# %%
import pandas as pd
from experiments_utils.results.tables import Tables

Tables.configure('./classification/decision_tree/')
df_class = pd.concat(Tables.query('*', 'metrics', as_pandas=True))
Tables.configure('./regression/decision_tree/')
df_reg = pd.concat(Tables.query('*', 'metrics', as_pandas=True))
Tables.configure('./survival/decision_tree/')
df_surv = pd.concat(Tables.query('*', 'metrics', as_pandas=True))
# Out:
# WARNING:root:Given tables directory: "./classification/decision_tree/" is not empty
# WARNING:root:Given tables directory: "./regression/decision_tree/" is not empty
# WARNING:root:Given tables directory: "./survival/decision_tree/" is not empty

# %%
df_reg.mean()
# Out:
# C:\Users\cezar\AppData\Local\Temp\ipykernel_25096\2284227468.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_reg.mean()
# RMSE (test)                      2.960648e-01
# MAE (test)                       2.291569e-01
# MAPE (test)                      1.431734e+14
# rRMSE (test)                     8.204749e-01
# rMAE (test)                      5.976073e-01
# rMAPE (test)                     1.431734e+12
# maxError (test)                  6.477344e-01
# R2 (test)                       -9.055608e-02
# RMSE (train)                     9.494732e-03
# MAE (train)                      4.280949e-03
# MAPE (train)                     1.225605e+11
# rRMSE (train)                    2.509607e-02
# rMAE (train)                     1.017060e-02
# ...

# %%
0.759
